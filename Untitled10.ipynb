# %% [markdown]
# <a href="https://colab.research.google.com/github/TungSoPon/BasicProg_DataViz65/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
pd.plotting.parallel_coordinates(df, 'Name')

# %% [markdown]
# ##S

# %%
pd.plotting.parallel_coordinates(df, 'Name' ,cols = ['SepalLength','PetalLength','SepalWidth','PetalWidth'])

# %%
pd.plotting.parallel_coordinates(df, 'Name' ,color = ['c','m','y'])

# %%
pd.plotting.parallel_coordinates(df, 'Name' ,color = [[1,1,0],[0.5,0,0.8],[0.2,0.4,0.7]])

# %%
pd.plotting.parallel_coordinates(df, 'Name' ,color = ['#A73B24','#52856D','#88B46C'])
