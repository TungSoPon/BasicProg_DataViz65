# %% [markdown]
# <a href="https://colab.research.google.com/github/TungSoPon/BasicProg_DataViz65/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##HW4

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,1.5,3,5,7,9,11,13,13.5],[5.5,5.25,4.9,5,4.8,5,4.9,5.2,5.6],'c-')
plt.plot([1,2,3,5,7,8,9,10.5,12,13.5],[5.5,6,6.2,6,6.25,6.2,6,6.2,6,5.6],'c-')
plt.plot([2.2,2.2,2.2,2.2],[3.5,4.5,4,5],'d', color='#5F9EA0')
plt.plot([3,3,3],[4.3,3.8,4.75,],'d', color='#5F9EA0')
plt.plot([4,4,4],[3.6,4.2,4.8,],'d', color='#5F9EA0')
plt.plot([5,5,5],[3.9,4.3,4.65,],'d', color='#5F9EA0')
plt.plot([6,6,6],[3.7,4.1,4.55,],'d', color='#5F9EA0')
plt.plot([7,7,7],[3.4,4.2,4.62,],'d', color='#5F9EA0')
plt.plot([8,8,8],[3.2,4.2,4.73,],'d', color='#5F9EA0')
plt.plot([9,9,9],[3.8,4.2,4.67,],'d', color='#5F9EA0')
plt.plot([10,10,10],[3.5,4.3,4.7,],'d', color='#5F9EA0')
plt.plot([11,11,11],[3.3,3.8,4.5,],'d', color='#5F9EA0')
plt.plot([12.5,12.5,12.5,12.5],[3.5,4.5,4,5],'d', color='#5F9EA0')

plt.text(6,5.5,'Rain',fontsize=20,color='b')
plt.title('Rain');
